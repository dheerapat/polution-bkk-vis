# %% [markdown]
# # pm 2.5 visualization in Bangkok

# %%
import pandas as pd
import numpy as np
import datetime as dt
import calmap
import matplotlib.pyplot as plt

from datetime import datetime

# %% [markdown]
# ### read csv data

# %%
data = pd.read_csv('pm2020.csv', parse_dates=['Date'])

# %% [markdown]
# ### first 5 row of data

# %%
data.head()
# Out:
#         Date   02T  05T   10T   11T   12T   59T   61T   03T   50T  ...   75T  \
# 0 2020-01-01  20.0   22  18.0  23.0  17.0  20.0  20.0  21.0  22.0  ...  17.0
# 1 2020-01-02  26.0   24  20.0  26.0  21.0  24.0  26.0  28.0  27.0  ...  14.0
# 2 2020-01-03  32.0   28  24.0  31.0  24.0  27.0  32.0  32.0  29.0  ...  10.0
# 3 2020-01-04  37.0   35  31.0  35.0  35.0  34.0  37.0  38.0  39.0  ...  15.0
# 4 2020-01-05  45.0   41  33.0  40.0  36.0  38.0  42.0  51.0  44.0  ...  19.0
#
#     76T   77T   78T  79T   80T   81T  82T  83T  84T
# 0  35.0  15.0  10.0   38   7.0  34.0  NaN  NaN  NaN
# 1  32.0  22.0   9.0   29   8.0  27.0  NaN  NaN  NaN
# 2  33.0  25.0   8.0   43   8.0  38.0  NaN  NaN  NaN
# 3  33.0  28.0   8.0   51   9.0  51.0  NaN  NaN  NaN
# 4  40.0  39.0   8.0   56  10.0  56.0  NaN  NaN  NaN
#
# [5 rows x 69 columns]

# %% [markdown]
# ### make "Date" column be index

# %%
data = data.set_index('Date')

# %%
data.head()
# Out:
#              02T  05T   10T   11T   12T   59T   61T   03T   50T   52T  ...  \
# Date                                                                   ...
# 2020-01-01  20.0   22  18.0  23.0  17.0  20.0  20.0  21.0  22.0  21.0  ...
# 2020-01-02  26.0   24  20.0  26.0  21.0  24.0  26.0  28.0  27.0  27.0  ...
# 2020-01-03  32.0   28  24.0  31.0  24.0  27.0  32.0  32.0  29.0  33.0  ...
# 2020-01-04  37.0   35  31.0  35.0  35.0  34.0  37.0  38.0  39.0  39.0  ...
# 2020-01-05  45.0   41  33.0  40.0  36.0  38.0  42.0  51.0  44.0  45.0  ...
#
#              75T   76T   77T   78T  79T   80T   81T  82T  83T  84T
# Date
# 2020-01-01  17.0  35.0  15.0  10.0   38   7.0  34.0  NaN  NaN  NaN
# 2020-01-02  14.0  32.0  22.0   9.0   29   8.0  27.0  NaN  NaN  NaN
# 2020-01-03  10.0  33.0  25.0   8.0   43   8.0  38.0  NaN  NaN  NaN
# 2020-01-04  15.0  33.0  28.0   8.0   51   9.0  51.0  NaN  NaN  NaN
# 2020-01-05  19.0  40.0  39.0   8.0   56  10.0  56.0  NaN  NaN  NaN
#
# [5 rows x 68 columns]

# %%
#plt.figure(figsize=(20,10))

# %%
calmap.yearplot(data['59T'], fillcolor='lightgrey',daylabels='MTWTFSS',
                dayticks=[0, 2, 4, 6],linewidth=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# [reference](https://towardsdatascience.com/create-githubs-style-contributions-plot-for-your-time-series-data-79df84ec93da)
